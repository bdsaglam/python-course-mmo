# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../io/forbes500.csv')

# %%
df
# Out:
#      Rank                          Company Name      Country  \
# 0       1                               Walmart          USA
# 1       2                            State Grid        China
# 2       3                         Sinopec Group        China
# 3       4              China National Petroleum        China
# 4       5                          Toyota Motor        Japan
# 5       7                     Royal Dutch Shell  Netherlands
# 6       9                                 Apple          USA
# 7      10                           Exxon Mobil          USA
# 8      11                              McKesson          USA
# 9      13                    UnitedHealth Group          USA
# 10     14                            CVS Health          USA
# 11     15                   Samsung Electronics  South Korea
# 12     17                               Daimler      Germany
# 13     18                        General Motors          USA
# ...

# %%
df.replace?

# %%
df['Country'].astype(np.unicode).values
# Out:
# array(['USA', 'China', 'China', 'China', 'Japan', 'Netherlands', 'USA',
#        'USA', 'USA', 'USA', 'USA', 'South Korea', 'Germany', 'USA', 'USA',
#        'Italy', 'USA', 'China', 'China', 'France', 'USA', 'Taiwan',
#        'China', 'Japan', 'France', 'USA', 'Japan', 'Germany', 'USA', 'USA',
#        'USA', 'China', 'China', 'USA', 'China', 'China', 'France', 'Japan',
#        'USA', 'USA', 'China', 'USA', 'Japan', 'China', 'Germany', 'USA',
#        'Netherlands', 'China', 'Britain', 'Italy', 'China', 'USA', 'USA',
#        'USA', 'USA', 'Russia', 'Switzerland', 'USA', 'Germany', 'France',
#        'China', 'USA', 'USA', 'Japan', 'Japan', 'Spain', 'USA', 'Germany',
#        'Germany', 'South Korea', 'USA', 'France', 'USA', 'France', 'China',
#        'Italy', 'USA', 'China', 'Japan', 'Britain', 'China', 'Britain',
#        'Britain', 'Netherlands', 'South Korea', 'USA', 'USA', 'USA',
#        'China', 'China', 'Russia', 'China', 'France', 'Japan', 'USA',
# ...

# %%
df['Country'] = df['Country'].apply(np.ast)

# %%
df['Country'].values
# Out:
# array(['USA', 'China', 'China', 'China', 'Japan', 'Netherlands', 'USA',
#        'USA', 'USA', 'USA', 'USA', 'South Korea', 'Germany', 'USA', 'USA',
#        'Italy', 'USA', 'China', 'China', 'France', 'USA', 'Taiwan',
#        'China', 'Japan', 'France', 'USA', 'Japan', 'Germany', 'USA', 'USA',
#        'USA', 'China', 'China', 'USA', 'China', 'China', 'France', 'Japan',
#        'USA', 'USA', 'China', 'USA', 'Japan', 'China', 'Germany', 'USA',
#        'Netherlands', 'China', 'Britain', 'Italy', 'China', 'USA', 'USA',
#        'USA', 'USA', 'Russia', 'Switzerland', 'USA', 'Germany', 'France',
#        'China', 'USA', 'USA', 'Japan', 'Japan', 'Spain', 'USA', 'Germany',
#        'Germany', 'South Korea', 'USA', 'France', 'USA', 'France', 'China',
#        'Italy', 'USA', 'China', 'Japan', 'Britain', 'China', 'Britain',
#        'Britain', 'Netherlands', 'South Korea', 'USA', 'USA', 'USA',
#        'China', 'China', 'Russia', 'China', 'France', 'Japan', 'USA',
# ...
